# %%
import os
from PublicDataReader import TransactionPrice

service_key = os.getenv("PUBLIC_DATA_HUB")


api = TransactionPrice(service_key)

# 단일 월 조회
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="11650",
    year_month="202212",
)

# 기간 내 조회
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="11650",
    start_year_month="202201",
    end_year_month="202212",
)

df.tail()
# Out:
#     법정동시군구코드 법정동읍면동코드 법정동지번코드 법정동본번코드 법정동부번코드      도로명 도로명시군구코드    도로명코드  \
# 685    11650    10800       1    1445    0014  서초중앙로2길    11650  4163718
# 686    11650    10600       1    0157    0000  신반포로33길    11650  4163453
# 687    11650    10800       1    1445    0004    서초중앙로    11650  3121024
# 688    11650    10800       1    1445    0004    서초중앙로    11650  3121024
# 689    11650    10800       1    1337    0003   효령로77길    11650  4163659
#
#     도로명일련번호코드 도로명지상지하코드  ...      단지일련번호  해제여부   해제사유발생일  거래유형  중개사소재지  등기일자  \
# 685        01         0  ...  11650-3284  None      None   직거래    None  None
# 686        01         0  ...   11650-102  None      None  중개거래  서울 서초구  None
# 687        03         0  ...   11650-518  None      None  중개거래  서울 서초구  None
# 688        03         0  ...   11650-518     O  22.12.09  중개거래  서울 서초구  None
# 689        01         0  ...  11650-4072  None      None  중개거래  서울 서초구  None
#
#      아파트동명   매도자   매수자  토지임대부아파트여부
# 685   None  None  None           N
# 686   None  None  None           N
# 687   None  None  None           N
# 688   None  None  None           N
# 689   None  None  None           N
#
# [5 rows x 32 columns]
